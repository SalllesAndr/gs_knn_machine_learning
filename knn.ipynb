# %% [markdown]
# <a href="https://colab.research.google.com/github/SalllesAndr/gs_knn_machine_learning/blob/main/knn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ANDERSON SALES RM 97960

# %% [markdown]
# Importando Dados

# %%
import pandas as pd
df = pd.read_csv('/content/dataset_energia.csv')
df.head()
# Out:
#      nome_cliente  consumo_kwh        regiao tipo_energia_consumida  classe
# 0      João Silva         2500       Sudeste                térmica       1
# 1  Maria Oliveira         2200           Sul           hidrelétrica       1
# 2   Carlos Santos         2100      Nordeste                 eólica       2
# 3       Ana Costa         1800  Centro-Oeste                térmica       2
# 4   Lucas Pereira         1500       Sudeste                térmica       2
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['consumo_kwh'].plot(kind='hist', bins=20, title='consumo_kwh')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['classe'].plot(kind='hist', bins=20, title='classe')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %% [markdown]
# Quantidade de Clientes

# %%
num_clientes = df['nome_cliente'].nunique()
print(f"There are {num_clientes} unique customers in the dataset.")
# Out:
# There are 92 unique customers in the dataset.

# %% [markdown]
# Limpando Possíveis Dados Nulos

# %%
df = df.dropna()

# %% [markdown]
# Limpando Espaços

# %%
df = df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

# %% [markdown]
# Importando KNN

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %% [markdown]
# Codificação das variáveis categóricas

# %%
df_encoded = pd.get_dummies(df, columns=["regiao", "tipo_energia_consumida"])

# %% [markdown]
# Definindo variáveis

# %%
X = df_encoded.drop("classe", axis=1)
y = df_encoded["classe"]

# %% [markdown]
# Pré-processamento

# %%
df.columns = df.columns.str.normalize("NFKD").str.encode("ascii", errors="ignore").str.decode("utf-8")
df["consumo_kwh"] = pd.to_numeric(df["consumo_kwh"], errors="coerce")
df.dropna(inplace=True)

# %% [markdown]
# Conversão de nomes

# %%
label_encoder = LabelEncoder()
df['nome_cliente'] = label_encoder.fit_transform(df['nome_cliente'].astype(str))

# %% [markdown]
# Codificação das variáveis categóricas (transforma 'regiao' e 'tipo_energia_consumida' em variáveis dummies)

# %%
df_encoded = pd.get_dummies(df, columns=["regiao", "tipo_energia_consumida"])

# %% [markdown]
# Separação entre as variáveis de entrada (X) e a variável de saída (y)

# %%
X = df_encoded.drop("classe", axis=1)
y = df_encoded["classe"]

# %% [markdown]
# Em vez de RandomForestClassifier, use KNeighborsClassifier:

# %%
knn_model = KNeighborsClassifier(n_neighbors=5)

# %% [markdown]
# Dimensionamento de recursos (importante para KNN)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# Treino do modelo

# %%
knn_model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# Fazendo previsões e avaliando o modelo

# %%
y_pred = knn_model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy of KNN model: {accuracy}")
# Out:
# Accuracy of KNN model: 0.9473684210526315

# %% [markdown]
# Imprimindo um relatório de classificação

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      0.75      0.86         4
#            2       0.94      1.00      0.97        15
#
#     accuracy                           0.95        19
#    macro avg       0.97      0.88      0.91        19
# weighted avg       0.95      0.95      0.94        19

# %% [markdown]
# Teste com dado aleatório

# %%
num_rows = X_test.shape[0]
indice_aleatorio = np.random.choice(num_rows)
dado_aleatorio = X_test[indice_aleatorio]
classe_real = y_test.iloc[indice_aleatorio]
classe_prevista = knn_model.predict([dado_aleatorio])[0]
print(f"Dado aleatório: {dado_aleatorio}")
print(f"Classe real: {classe_real}")
print(f"Classe prevista: {classe_prevista}")
# Out:
# Dado aleatório: [ 1.26885015 -0.54053668 -0.47907014 -0.39223227 -0.26726124 -0.68599434
#   1.55212464 -0.5         1.55212464 -1.01342342]
# Classe real: 2
# Classe prevista: 2
